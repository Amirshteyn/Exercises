# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirshteyn/Exercises/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22DATA_WORKING%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Fraw.githubusercontent.com%2Fybg345%2Fdata-analysis-viz-excel%2Fmaster%2FData%2520Visualization%2520Charts%2520%2526%2520Graphs%2520with%2520MS%2520Excel%2FBasic%2520%2526%2520Advanced%2520Chart%2520Types-Hands%2520on%2520Practice%2FAdvanced%2520Charts%2520Hands%2520on%2520Practice.xlsx&wdOrigin=BROWSELINK
# Out:
# The destination name is too long (274), reducing to 236
# --2023-12-11 09:11:31--  https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Fraw.githubusercontent.com%2Fybg345%2Fdata-analysis-viz-excel%2Fmaster%2FData%2520Visualization%2520Charts%2520%2526%2520Graphs%2520with%2520MS%2520Excel%2FBasic%2520%2526%2520Advanced%2520Chart%2520Types-Hands%2520on%2520Practice%2FAdvanced%2520Charts%2520Hands%2520on%2520Practice.xlsx
# Resolving view.officeapps.live.com (view.officeapps.live.com)... 52.108.8.12, 52.108.9.12, 2603:1063:2000::12, ...
# Connecting to view.officeapps.live.com (view.officeapps.live.com)|52.108.8.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie:  at position 0.
# Length: unspecified [text/html]
# ...

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93
# Receiving objects: 100% (145/145), 9.72 MiB | 12.66 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
import pandas as pd
df = pd.read_csv('praktikum_datasets/merc.csv')
df.head()

# %%
pd.read_excel('praktikum_datasets/uzbekistan.xlsx', index_col=0, names=['hudud','maydon','aholi'] )
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv("praktikum_datasets/automobile_data.csv", nrows=5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage  price
# 0             four         111               21  13495
# 1             four         111               21  16500
# 2              six         154               19  16500
# 3             four         102               24  13950
# 4             five         115               18  17450

# %%
AI = pd.read_html('https://en.wikipedia.org/wiki/Artificial_intelligence')

# %%
len(AI)
# Out:
# 17

# %%
AI[8]
# Out:
#               0                                                  1
# 0  Audio–visual  AlexNet WaveNet Human image synthesis HWR OCR ...
# 1        Verbal  Word2vec Seq2seq BERT Gemini LaMDA Bard NMT Pr...
# 2    Decisional  AlphaGo AlphaZero Q-learning SARSA OpenAI Five...
