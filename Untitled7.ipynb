# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirshteyn/Exercises/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Yil':[2021,2020,2019, 2018, 2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9, 32.5, 30,27,23.7,21.3],
    'Temp':[2021,2020,2019, 2018, 2017,2016,2015,2010],
    'Zichlik':[2021,2020,2019, 2018, 2017,2016,2015,2010],

}
df = pd.DataFrame(data)
df

# %%
data = df['Aholi soni']
data

# %%
obj = pd.Series(np.arange(8.), ['a','b','c','d', 'e','f','g','h'])
obj

# %%
obj[[2,7]] = 11
obj[obj<11]

# %%
uz = {2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9, 2016:31.4, 2015:30.9}
kz = {2020:18.8, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8, 2015:17.6}
tj= {2020:9.5, 2019:9.3, 2018:8.9, 2017:8.7, 2016:8.7, 2015:8.5}
kg= {2020:6.5, 2019:6.4, 2018:6.3, 2017:6.2, 2016:6.1, 2015:6.0}
tr= {2020:6.0, 2019:5.4, 2018:5.3, 2017:5.2, 2016:5.1, 2015:5.0}
df = pd.DataFrame({
    'Uzbekistan':uz,
    'Kazakhstan':kz,
    'Tajikistan':tj,
    'Kyrgizstan':kg,
    'Turkmenistan':tr
    })

# %%
df
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.5         9.3         6.4           5.4
# 2018        32.5        18.3         8.9         6.3           5.3
# 2017        31.9        18.1         8.7         6.2           5.2
# 2016        31.4        17.8         8.7         6.1           5.1
# 2015        30.9        17.6         8.5         6.0           5.0

# %%
df['Uzbekistan'] #SERIES
df[['Uzbekistan']] #Dataframe
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5
# 2017        31.9
# 2016        31.4
# 2015        30.9

# %%
df[['Uzbekistan','Tajikistan']]
# Out:
#       Uzbekistan  Tajikistan
# 2020        33.5         9.5
# 2019        32.9         9.3
# 2018        32.5         8.9
# 2017        31.9         8.7
# 2016        31.4         8.7
# 2015        30.9         8.5

# %%
df[3:]
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgizstan  Turkmenistan
# 2017        31.9        18.1         8.7         6.2           5.2
# 2016        31.4        17.8         8.7         6.1           5.1
# 2015        30.9        17.6         8.5         6.0           5.0
